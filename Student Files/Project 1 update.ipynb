# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
import scipy.stats as st

# %%
# Reference the file where the CSV and JSON's are located
education_csv = "Resources/Education.csv"
education_json = "Resources/json_education.json"
price_csv = "Resources/Housing_Price.csv"
price_json = "Resources/json_housing_price.json"
income_csv = "Resources/Income.csv"
higher_education_csv = "Resources/HigherEducation.csv"

# Import the data into a Pandas DataFrame
education1_df = pd.read_csv(education_csv)
education2_df = pd.read_json(education_json)
price1_df = pd.read_csv(price_csv)
price2_df = pd.read_json(price_json)
income_df = pd.read_csv(income_csv, on_bad_lines='skip')
HigherEd_df = pd.read_csv(higher_education_csv)

# %%
merge_csv1_df = pd.merge(education1_df, price1_df, on="state", how="outer")
merge_csv1_df["MedianValue"] = merge_csv1_df["MedianValue"]
merge_csv1_df["medianValueZillow"] = merge_csv1_df["medianValueZillow"]

# %%
merge_csv2_df = pd.merge(merge_csv1_df, HigherEd_df, on="state", how="outer")

# %%
merge_csv3_df = pd.merge(merge_csv2_df, income_df, on="state", how="outer")
merge_csv3_df["HouseholdIncome"] = merge_csv3_df["HouseholdIncome"]

# %%
State_df = merge_csv3_df.rename(columns={"state":"State", "publicSchoolScore":"School Score", "qualityRank":"School Quality Ranking", "safetyRank":"School Safety Ranking","MedianValue":"Median Home Value", "medianValueZillow":"Median Home Value on Zillow", "PercentHighSchoolOrHigher":"Percent of High School Graduates", "PercentBachelorsOrHigher":"Percent of High Education Graduates", "HouseholdIncome": "Average Income" })
State_df
# Out:
#              State  School Score  School Quality Ranking  \
# 0    Massachusetts         73.14                       1
# 1      Connecticut         67.50                       2
# 2       New Jersey         64.36                       3
# 3         Virginia         61.71                       5
# 4    New Hampshire         61.57                       4
# 5         Maryland         60.24                       8
# 6         Delaware         58.07                      16
# 7         Nebraska         57.81                      12
# 8        Wisconsin         57.48                       6
# 9          Vermont         57.43                      15
# 10    Rhode Island         57.21                      13
# 11       Minnesota         57.00                       7
# 12           Maine         56.87                      18
# 13        New York         56.42                      11
# 14        Illinois         56.27                       9
# 15            Utah         55.87                      17
# 16    North Dakota         55.30                      10
# 17         Florida         55.22                      14
# 18        Kentucky         54.18                      23
# 19            Iowa         53.71                      22
# 20        Colorado         53.70                      20
# 21         Indiana         53.31                      25
# 22         Wyoming         53.07                      24
# 23    Pennsylvania         52.86                      19
# 24    South Dakota         52.43                      21
# 25      Washington         51.31                      27
# 26         Montana         50.33                      26
# 27           Texas         49.86                      31
# 28          Kansas         47.47                      28
# 29            Ohio         47.43                      33
# 30       Tennessee         46.93                      30
# 31         Georgia         46.22                      37
# 32  North Carolina         46.06                      38
# 33        Michigan         45.92                      32
# 34        Missouri         45.88                      29
# 35           Idaho         45.20                      35
# 36        Arkansas         43.84                      40
# 37          Nevada         43.64                      39
# 38          Hawaii         43.09                      41
# 39      California         42.42                      36
# 40          Oregon         40.96                      42
# 41  South Carolina         38.94                      43
# 42   West Virginia         38.47                      45
# 43     Mississippi         38.22                      44
# 44        Oklahoma         37.15                      46
# 45         Alabama         37.02                      48
# 46          Alaska         36.43                      47
# 47         Arizona         35.13                      49
# 48       Louisiana         33.37                      50
# 49      New Mexico         25.26                      51
#
#     School Safety Ranking  Median Home Value  Median Home Value on Zillow  \
# 0                       1             398800                       559312
# 1                       9             279700                       343687
# 2                      19             343500                       441762
# 3                       2             282800                       358447
# 4                      12             272300                       411945
# 5                       4             325400                       390608
# 6                       3             258300                       337543
# 7                       8             164000                       230672
# 8                      28             189200                       251655
# 9                       6             230900                       336310
# 10                     10             276600                       412897
# 11                     36             235700                       323515
# 12                      7             198000                       344592
# 13                     16             325000                       382663
# 14                     24             202100                       253433
# 15                     15             305400                       544868
# 16                     31             199900                       266763
# 17                     20             232000                       358018
# 18                     14             147100                       188439
# 19                     18             153900                       183418
# 20                     23             369900                       559838
# 21                     11             148900                       210166
# 22                     22             228000                       308862
# 23                     33             187500                       254597
# 24                     35             174600                       277809
# 25                      5             366800                       595732
# 26                     37             244900                       428202
# 27                     13             187200                       289896
# 28                     41             157600                       198199
# 29                     26             151400                       199959
# 30                     44             177600                       276963
# 31                     27             190200                       295159
# 32                     29             182100                       296021
# 33                     43             162600                       225324
# 34                     50             163600                       218208
# 35                     42             235600                       466435
# 36                     40             133600                       169867
# 37                     46             290200                       434832
# 38                     32             636400                       848926
# 39                     51             538500                       760800
# 40                     39             336700                       502215
# 41                     48             170100                       269186
# 42                     17             123200                       129103
# 43                     38             125500                       157828
# 44                     25             142400                       171057
# 45                     21             149600                       194695
# 46                     30             275600                       312988
# 47                     34             242000                       416433
# 48                     45             168100                       205972
# 49                     49             175700                       277617
#
#     Percent of High School Graduates  Percent of High Education Graduates  \
# 0                               91.1                                 44.5
# 1                               90.9                                 40.0
# 2                               90.3                                 40.7
# 3                               90.3                                 39.5
# 4                               93.3                                 37.6
# 5                               90.6                                 40.9
# 6                               90.6                                 32.7
# 7                               91.6                                 32.5
# 8                               92.6                                 30.8
# 9                               93.5                                 39.7
# 10                              89.2                                 35.0
# 11                              93.4                                 36.8
# 12                              93.2                                 32.5
# 13                              87.2                                 37.5
# 14                              89.7                                 35.5
# 15                              93.0                                 34.7
# 16                              93.1                                 30.7
# 17                              88.5                                 30.5
# 18                              87.2                                 25.0
# 19                              92.5                                 29.3
# 20                              92.1                                 41.6
# 21                              89.3                                 27.2
# 22                              93.6                                 28.2
# 23                              91.0                                 32.3
# 24                              92.2                                 29.3
# 25                              91.7                                 36.7
# 26                              94.0                                 33.1
# 27                              84.4                                 30.7
# 28                              91.4                                 33.9
# 29                              90.8                                 28.9
# 30                              88.2                                 28.2
# 31                              87.9                                 32.2
# 32                              88.5                                 32.0
# 33                              91.3                                 30.0
# 34                              90.6                                 29.9
# 35                              91.3                                 28.7
# 36                              87.2                                 23.8
# 37                              86.9                                 25.5
# 38                              92.5                                 33.6
# 39                              83.9                                 34.7
# 40                              91.1                                 34.4
# 41                              88.3                                 29.0
# 42                              87.6                                 21.3
# 43                              85.3                                 22.8
# 44                              88.6                                 26.1
# 45                              86.9                                 26.2
# 46                              93.1                                 30.0
# 47                              87.9                                 30.3
# 48                              85.9                                 24.9
# 49                              86.5                                 28.1
#
#     Average Income
# 0            84385
# 1            79855
# 2            85245
# 3            76398
# 4            77923
# 5            87063
# 6            69110
# 7            63015
# 8            63293
# 9            63477
# 10           70305
# 11           73382
# 12           59489
# 13           71117
# 14           68428
# 15           74197
# 16           65315
# 17           57703
# 18           52238
# 19           61836
# 20           75231
# 21           58235
# 22           65304
# 23           63627
# 24           59896
# 25           77006
# 26           56539
# 27           63826
# 28           61091
# 29           58116
# 30           54833
# 31           61224
# 32           56642
# 33           59234
# 34           57290
# 35           58915
# 36           49475
# 37           62043
# 38           83173
# 39           78672
# 40           65667
# 41           54864
# 42           48037
# 43           46511
# 44           53840
# 45           52035
# 46           77790
# 47           61529
# 48           50800
# 49           51243

# %%
State_df["Region"]= 1

State_df.loc[(State_df["State"] == "Connecticut")|(State_df["State"] == "Maine")|(State_df["State"] == "Massachusetts")
             |(State_df["State"] == "New Hampshire")|(State_df["State"] == "Rhode Island")|(State_df["State"] == "Vermont"),"Region"] = "New England Division" 
State_df.loc[(State_df["State"] == "New Jersey")|(State_df["State"] == "New York")|(State_df["State"] == "Pennsylvania"),"Region"] = "Middle Atlantic Division"
State_df.loc[(State_df["State"] == "Illinois")|(State_df["State"] == "Indiana")|(State_df["State"] == "Michigan")
             |(State_df["State"] == "Ohio")|(State_df["State"] == "Wisconsin"),"Region"] = "East North Central Division"

State_df.loc[(State_df["State"] == "Iowa")|(State_df["State"] == "Kansas")|(State_df["State"] == "Minnesota")
             |(State_df["State"] == "Missouri")|(State_df["State"] == "Nebraska")|
             (State_df["State"] == "North Dakota")|(State_df["State"] == "South Dakota"),"Region"] = "West North Central Division"

State_df.loc[(State_df["State"] == "Delaware")|(State_df["State"] == "Florida")|(State_df["State"] == "Georgia")
             |(State_df["State"] == "Maryland")|(State_df["State"] == "North Carolina")|
             (State_df["State"] == "South Carolina")|(State_df["State"] == "Virginia")|(State_df["State"] == "West Virginia"),"Region"] = "South Atlantic Division"

State_df.loc[(State_df["State"] == "Alabama")|(State_df["State"] == "Kentucky")|(State_df["State"] == "Mississippi")
             |(State_df["State"] == "Tennessee"),"Region"] = "East South Central Division"

State_df.loc[(State_df["State"] == "Arkansas")|(State_df["State"] == "Louisiana")|(State_df["State"] == "Oklahoma")
             |(State_df["State"] == "Texas"),"Region"] = "West South Central Division"

State_df.loc[(State_df["State"] == "Arizona")|(State_df["State"] == "Colorado")|(State_df["State"] == "Idaho")
             |(State_df["State"] == "Montana")|(State_df["State"] == "Nevada")|
             (State_df["State"] == "New Mexico")|(State_df["State"] == "Utah")|(State_df["State"] == "Wyoming"),"Region"] = "West Region"

State_df.loc[(State_df["State"] == "Alaska")|(State_df["State"] == "California")|(State_df["State"] == "Hawaii")
             |(State_df["State"] == "Oregon")|(State_df["State"] == "Washington"),"Region"] = "Pacific Division"
State_df

bins2 = [20, 29,39,49]
group_labels = ["Graduates 20-29","Graduates 30-39","Graduates 40-49" ]
State_df["Graduate Bin"] = pd.cut(State_df["Percent of High Education Graduates"],bins2,labels=group_labels,include_lowest=True)
State_df
# Out:
#              State  School Score  School Quality Ranking  \
# 0    Massachusetts         73.14                       1
# 1      Connecticut         67.50                       2
# 2       New Jersey         64.36                       3
# 3         Virginia         61.71                       5
# 4    New Hampshire         61.57                       4
# 5         Maryland         60.24                       8
# 6         Delaware         58.07                      16
# 7         Nebraska         57.81                      12
# 8        Wisconsin         57.48                       6
# 9          Vermont         57.43                      15
# 10    Rhode Island         57.21                      13
# 11       Minnesota         57.00                       7
# 12           Maine         56.87                      18
# 13        New York         56.42                      11
# 14        Illinois         56.27                       9
# 15            Utah         55.87                      17
# 16    North Dakota         55.30                      10
# 17         Florida         55.22                      14
# 18        Kentucky         54.18                      23
# 19            Iowa         53.71                      22
# 20        Colorado         53.70                      20
# 21         Indiana         53.31                      25
# 22         Wyoming         53.07                      24
# 23    Pennsylvania         52.86                      19
# 24    South Dakota         52.43                      21
# 25      Washington         51.31                      27
# 26         Montana         50.33                      26
# 27           Texas         49.86                      31
# 28          Kansas         47.47                      28
# 29            Ohio         47.43                      33
# 30       Tennessee         46.93                      30
# 31         Georgia         46.22                      37
# 32  North Carolina         46.06                      38
# 33        Michigan         45.92                      32
# 34        Missouri         45.88                      29
# 35           Idaho         45.20                      35
# 36        Arkansas         43.84                      40
# 37          Nevada         43.64                      39
# 38          Hawaii         43.09                      41
# 39      California         42.42                      36
# 40          Oregon         40.96                      42
# 41  South Carolina         38.94                      43
# 42   West Virginia         38.47                      45
# 43     Mississippi         38.22                      44
# 44        Oklahoma         37.15                      46
# 45         Alabama         37.02                      48
# 46          Alaska         36.43                      47
# 47         Arizona         35.13                      49
# 48       Louisiana         33.37                      50
# 49      New Mexico         25.26                      51
#
#     School Safety Ranking  Median Home Value  Median Home Value on Zillow  \
# 0                       1             398800                       559312
# 1                       9             279700                       343687
# 2                      19             343500                       441762
# 3                       2             282800                       358447
# 4                      12             272300                       411945
# 5                       4             325400                       390608
# 6                       3             258300                       337543
# 7                       8             164000                       230672
# 8                      28             189200                       251655
# 9                       6             230900                       336310
# 10                     10             276600                       412897
# 11                     36             235700                       323515
# 12                      7             198000                       344592
# 13                     16             325000                       382663
# 14                     24             202100                       253433
# 15                     15             305400                       544868
# 16                     31             199900                       266763
# 17                     20             232000                       358018
# 18                     14             147100                       188439
# 19                     18             153900                       183418
# 20                     23             369900                       559838
# 21                     11             148900                       210166
# 22                     22             228000                       308862
# 23                     33             187500                       254597
# 24                     35             174600                       277809
# 25                      5             366800                       595732
# 26                     37             244900                       428202
# 27                     13             187200                       289896
# 28                     41             157600                       198199
# 29                     26             151400                       199959
# 30                     44             177600                       276963
# 31                     27             190200                       295159
# 32                     29             182100                       296021
# 33                     43             162600                       225324
# 34                     50             163600                       218208
# 35                     42             235600                       466435
# 36                     40             133600                       169867
# 37                     46             290200                       434832
# 38                     32             636400                       848926
# 39                     51             538500                       760800
# 40                     39             336700                       502215
# 41                     48             170100                       269186
# 42                     17             123200                       129103
# 43                     38             125500                       157828
# 44                     25             142400                       171057
# 45                     21             149600                       194695
# 46                     30             275600                       312988
# 47                     34             242000                       416433
# 48                     45             168100                       205972
# 49                     49             175700                       277617
#
#     Percent of High School Graduates  Percent of High Education Graduates  \
# 0                               91.1                                 44.5
# 1                               90.9                                 40.0
# 2                               90.3                                 40.7
# 3                               90.3                                 39.5
# 4                               93.3                                 37.6
# 5                               90.6                                 40.9
# 6                               90.6                                 32.7
# 7                               91.6                                 32.5
# 8                               92.6                                 30.8
# 9                               93.5                                 39.7
# 10                              89.2                                 35.0
# 11                              93.4                                 36.8
# 12                              93.2                                 32.5
# 13                              87.2                                 37.5
# 14                              89.7                                 35.5
# 15                              93.0                                 34.7
# 16                              93.1                                 30.7
# 17                              88.5                                 30.5
# 18                              87.2                                 25.0
# 19                              92.5                                 29.3
# 20                              92.1                                 41.6
# 21                              89.3                                 27.2
# 22                              93.6                                 28.2
# 23                              91.0                                 32.3
# 24                              92.2                                 29.3
# 25                              91.7                                 36.7
# 26                              94.0                                 33.1
# 27                              84.4                                 30.7
# 28                              91.4                                 33.9
# 29                              90.8                                 28.9
# 30                              88.2                                 28.2
# 31                              87.9                                 32.2
# 32                              88.5                                 32.0
# 33                              91.3                                 30.0
# 34                              90.6                                 29.9
# 35                              91.3                                 28.7
# 36                              87.2                                 23.8
# 37                              86.9                                 25.5
# 38                              92.5                                 33.6
# 39                              83.9                                 34.7
# 40                              91.1                                 34.4
# 41                              88.3                                 29.0
# 42                              87.6                                 21.3
# 43                              85.3                                 22.8
# 44                              88.6                                 26.1
# 45                              86.9                                 26.2
# 46                              93.1                                 30.0
# 47                              87.9                                 30.3
# 48                              85.9                                 24.9
# 49                              86.5                                 28.1
#
#     Average Income                       Region     Graduate Bin
# 0            84385         New England Division  Graduates 40-49
# 1            79855         New England Division  Graduates 40-49
# 2            85245     Middle Atlantic Division  Graduates 40-49
# 3            76398      South Atlantic Division  Graduates 40-49
# 4            77923         New England Division  Graduates 30-39
# 5            87063      South Atlantic Division  Graduates 40-49
# 6            69110      South Atlantic Division  Graduates 30-39
# 7            63015  West North Central Division  Graduates 30-39
# 8            63293  East North Central Division  Graduates 30-39
# 9            63477         New England Division  Graduates 40-49
# 10           70305         New England Division  Graduates 30-39
# 11           73382  West North Central Division  Graduates 30-39
# 12           59489         New England Division  Graduates 30-39
# 13           71117     Middle Atlantic Division  Graduates 30-39
# 14           68428  East North Central Division  Graduates 30-39
# 15           74197                  West Region  Graduates 30-39
# 16           65315  West North Central Division  Graduates 30-39
# 17           57703      South Atlantic Division  Graduates 30-39
# 18           52238  East South Central Division  Graduates 20-29
# 19           61836  West North Central Division  Graduates 30-39
# 20           75231                  West Region  Graduates 40-49
# 21           58235  East North Central Division  Graduates 20-29
# 22           65304                  West Region  Graduates 20-29
# 23           63627     Middle Atlantic Division  Graduates 30-39
# 24           59896  West North Central Division  Graduates 30-39
# 25           77006             Pacific Division  Graduates 30-39
# 26           56539                  West Region  Graduates 30-39
# 27           63826  West South Central Division  Graduates 30-39
# 28           61091  West North Central Division  Graduates 30-39
# 29           58116  East North Central Division  Graduates 20-29
# 30           54833  East South Central Division  Graduates 20-29
# 31           61224      South Atlantic Division  Graduates 30-39
# 32           56642      South Atlantic Division  Graduates 30-39
# 33           59234  East North Central Division  Graduates 30-39
# 34           57290  West North Central Division  Graduates 30-39
# 35           58915                  West Region  Graduates 20-29
# 36           49475  West South Central Division  Graduates 20-29
# 37           62043                  West Region  Graduates 20-29
# 38           83173             Pacific Division  Graduates 30-39
# 39           78672             Pacific Division  Graduates 30-39
# 40           65667             Pacific Division  Graduates 30-39
# 41           54864      South Atlantic Division  Graduates 20-29
# 42           48037      South Atlantic Division  Graduates 20-29
# 43           46511  East South Central Division  Graduates 20-29
# 44           53840  West South Central Division  Graduates 20-29
# 45           52035  East South Central Division  Graduates 20-29
# 46           77790             Pacific Division  Graduates 30-39
# 47           61529                  West Region  Graduates 30-39
# 48           50800  West South Central Division  Graduates 20-29
# 49           51243                  West Region  Graduates 20-29

# %%
Graduates_df = State_df.groupby("Graduate Bin")
Graduates_df = Graduates_df.mean()
Graduates_df

cols2 = ["Median Home Value","Median Home Value on Zillow","Percent of High School Graduates",
"Percent of High Education Graduates","Average Income"]

Graduates_df = Graduates_df[cols2].round(2)
Graduates_df
# Out:
#                  Median Home Value  Median Home Value on Zillow  \
# Graduate Bin
# Graduates 20-29          171133.33                    244065.40
# Graduates 30-39          252096.43                    365088.96
# Graduates 40-49          318714.29                    427137.71
#
#                  Percent of High School Graduates  \
# Graduate Bin
# Graduates 20-29                             88.24
# Graduates 30-39                             90.69
# Graduates 40-49                             91.26
#
#                  Percent of High Education Graduates  Average Income
# Graduate Bin
# Graduates 20-29                                26.26        54432.60
# Graduates 30-39                                32.83        66368.54
# Graduates 40-49                                40.99        78807.71

# %%
region_df = State_df.groupby("Region")
region_df = region_df.mean()
cols = ["Median Home Value", "Median Home Value on Zillow","Percent of High School Graduates", "Average Income",
        "Percent of High Education Graduates","School Score"]
region_df[cols]=region_df[cols].round(2)
region_df
# Out:
#                              School Score  School Quality Ranking  \
# Region
# East North Central Division         52.08               21.000000
# East South Central Division         44.09               36.250000
# Middle Atlantic Division            57.88               11.000000
# New England Division                62.29                8.833333
# Pacific Division                    42.84               38.600000
# South Atlantic Division             50.62               25.750000
# West North Central Division         52.80               18.428571
# West Region                         45.28               32.625000
# West South Central Division         41.06               41.750000
#
#                              School Safety Ranking  Median Home Value  \
# Region
# East North Central Division              26.400000          170840.00
# East South Central Division              29.250000          149950.00
# Middle Atlantic Division                 22.666667          285333.33
# New England Division                      7.500000          276050.00
# Pacific Division                         31.400000          430800.00
# South Atlantic Division                  18.750000          220512.50
# West North Central Division              31.285714          178471.43
# West Region                              33.500000          261462.50
# West South Central Division              30.750000          157825.00
#
#                              Median Home Value on Zillow  \
# Region
# East North Central Division                    228107.40
# East South Central Division                    204481.25
# Middle Atlantic Division                       359674.00
# New England Division                           401457.17
# Pacific Division                               604132.20
# South Atlantic Division                        304260.62
# West North Central Division                    242654.86
# West Region                                    429635.88
# West South Central Division                    209198.00
#
#                              Percent of High School Graduates  \
# Region
# East North Central Division                             90.74
# East South Central Division                             86.90
# Middle Atlantic Division                                89.50
# New England Division                                    91.87
# Pacific Division                                        90.46
# South Atlantic Division                                 89.04
# West North Central Division                             92.11
# West Region                                             90.66
# West South Central Division                             86.52
#
#                              Percent of High Education Graduates  \
# Region
# East North Central Division                                30.48
# East South Central Division                                25.55
# Middle Atlantic Division                                   36.83
# New England Division                                       38.22
# Pacific Division                                           33.88
# South Atlantic Division                                    32.26
# West North Central Division                                31.77
# West Region                                                31.28
# West South Central Division                                26.38
#
#                              Average Income
# Region
# East North Central Division        61461.20
# East South Central Division        51404.25
# Middle Atlantic Division           73329.67
# New England Division               72572.33
# Pacific Division                   76461.60
# South Atlantic Division            63880.12
# West North Central Division        63117.86
# West Region                        63125.12
# West South Central Division        54485.25

# %%
x1_axis = State_df["Region"].unique()
y1_axis = region_df["Median Home Value"]
plt.figure(figsize=(10,6))
plt.bar(x1_axis,y1_axis,align="center")
tick_locations = [value for value in x1_axis]
plt.xticks(tick_locations,rotation='vertical')
plt.title("Region by Average Home Value")
plt.xlabel("Region")
plt.ylabel("Average Home Value")
# Out:
# Text(0, 0.5, 'Average Home Value')

# %% [markdown]
# Region by Average Income
#
# The graph shows the average income by region.  The regions are breakdown by a list of states that can be found on the Census (https://www.census.gov/programs-surveys/economic-census/guidance-geographies/levels.html).  Each region provides what the current average income is leaving in the various region.

# %%
x_axis = State_df["Graduate Bin"].unique()
x_axis =list(x_axis)
x_axis.sort(reverse=False)
y_axis = Graduates_df["Average Income"]

plt.figure(figsize=(10,6))

plt.bar(x_axis,y_axis,align="center",color="r")
plt.title("Income by Average Percent of Graduates")
plt.xlabel("Graduate Range")
plt.ylabel("Average Income")
# Out:
# Text(0, 0.5, 'Average Income')

# %% [markdown]
# Income by Average Percentage of Graduates
#
# The graph average income based on the percentage of graduates among the states.  The lower percentage of people with graduate degrees in specific states represent a lower income level.  The higher percentage of people with graduate degree represent a higher income percentage.

# %%
x2 = State_df["Average Income"]
y2 = State_df["Median Home Value"]
(slope,intercept,rvalue,pvalue,stderr )=linregress(x2,y2)
regress_values = x2*slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x2, y2, marker='o',facecolors="green",edgecolors="red")
plt.plot(x2,regress_values,"r-")
plt.annotate(line_eq,(55000,500000),fontsize =13,color ="black")
# Out:
# Text(55000, 500000, 'y = 7.58x + -252209.41')
